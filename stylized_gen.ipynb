# %% [markdown]
# ### Create stylized morphology
# #### Function for creating stylized morphology in swc format

# %%
from stylized_swc import gen_stylized_swc, plot_morphology_swc
# %matplotlib notebook

# %% [markdown]
# #### A dataframe with geometry parameters
# The stylized model lies in xy-plane and is symmetric about yz-plane and around y-axis. Soma locates at the origin.
# name: Name of parts in the morphology.
# type: Type id in swc format.
# axial: If true, a single stick along y-axis. If false, two sticks on each side of yz-plane.
# L: Length of stick (um).
# R: Radius of sections (um).
# ang: Angle between stick and x-axis in radian \[-pi/2,pi.2\].
# pid: ID in the dataframe of parent to which current part attaches.

# %%
import pandas as pd

# The parameters in this file is converted from the detailed morphology algorimically (stylized_model.ipynb).
geo_prop = pd.read_csv('geom_parameters.csv',index_col='id')
geo_prop
# Out:
#       name  type  axial        L       R       ang  pid
# id
# 0     soma     1   True    0.000  6.6606  0.000000    0
# 1     axon     2   True   34.608  0.3240 -1.570796    0
# 2    basal     3  False  203.727  0.2420 -0.665215    0
# 3   apical     4  False  163.950  0.2200  0.000000    0
# 4    trunk     4   True  486.773  0.3100  1.570796    0
# 5     tuft     4  False  137.258  0.1760  0.920738    4

# %%
# creating swc format data
styl = gen_stylized_swc(geo_prop)
styl
# Out:
#      type          x           y    z       r  pid
# id
# 1       1   0.000000    0.000000  0.0  6.6606   -1
# 2       2   0.000000   -4.944000  0.0  0.3240    1
# 3       2   0.000000   -9.888000  0.0  0.3240    2
# 4       2   0.000000  -14.832000  0.0  0.3240    3
# 5       2   0.000000  -19.776000  0.0  0.3240    4
# ..    ...        ...         ...  ...     ...  ...
# 306     4 -71.205454  580.427891  0.0  0.1760  305
# 307     4 -74.172348  584.330178  0.0  0.1760  306
# 308     4 -77.139242  588.232465  0.0  0.1760  307
# 309     4 -80.106136  592.134752  0.0  0.1760  308
# 310     4 -83.073030  596.037039  0.0  0.1760  309
#
# [310 rows x 6 columns]

# %% [markdown]
# #### Suggested changes in the parameters

# %%
# Fix 45 degree for branch angle of basal dendrite and tuft for a generalized model. (potentially adjustable)
geo_prop.loc[[2,5],'ang'] = 45/180*np.pi

# Possibly most influential paramters (to be hand crafted or inferred by SNPE):
# Radius of soma
geo_prop.loc[1,['R']]
# Length and radius of the trunk
geo_prop.loc[4,['L','R']]

# Other potentially adjustable parameters (to be further inferred for polishing the model):
# Length and radius of dendrites (basal,apical,tuft, id: 2,3,5)
# Out:
# L    486.773
# R       0.31
# Name: 4, dtype: object

# %% [markdown]
# #### Write swc file to the bmtk components path

# %%
import os
styl = gen_stylized_swc(geo_prop,dL=20.)

# write swc file in bmtk path
dest = 'sim_details/components/morphologies'
styl_file = os.path.join(os.getcwd(),dest,'stylized.swc')
with open(styl_file,'w') as f:
    f.write('# id,type,x,y,z,r,pid\n')
styl.to_csv(styl_file,sep=' ',header=False,float_format='%.4f',mode='a')

# %% [markdown]
# #### Plot morphology

# %%
fig,ax = plot_morphology_swc(styl)
ax.elev = 89.
ax.azim = -90.
ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# <img src="data:image/png;base64,..." width="800">
# Text(0.5, 0, 'y')

# %% [markdown]
# ### Build bmtk model

# %%
from bmtk.builder.networks import NetworkBuilder
import numpy as np

net = NetworkBuilder('mcortex')
net.add_nodes(cell_name='stylized',
              positions = np.zeros((1,3)),
              potental='exc',
              model_type='biophysical',
              model_template='ctdb:Biophys1.hoc',
              model_processing='aibs_perisomatic',
              dynamics_params='fit_488695444_f9.json', #from allen database
              morphology= 'stylized.swc')

# %%
# %%bash
# rm network/*

# %%
net.build()
net.save_nodes(output_dir='network')

# %% [markdown]
# Need to check the current injection amplitude to ensure an action potential but the input is not too strong.

# %%
from bmtk.utils.sim_setup import build_env_bionet

build_env_bionet(base_dir='sim_details',      # Where to save the scripts and config files 
                 network_dir='network',    # Location of directory containing network files
                 tstop=15.0, dt=0.025,     # Run a simulation for 2000 ms at 0.025 ms intervals
                 report_vars=['v','i_membrane_','ecp'], # Tells simulator we want to record membrane potential and calcium traces
                 current_clamp={
                     'amp': 5.0,
                     'delay': 4.9,
                     'duration': 0.1
                 },
                 include_examples=True,    # Copies components files
                 compile_mechanisms=True   # Will try to compile NEURON mechanisms
                )

# %%
import pandas as pd

# save electrode position to file
filelocation = 'sim_details/components/recXelectrodes/linear_electrode.csv'
df = {'channel': 0}
df.update({x+'_pos': 0. for x in list('xyz')})
df = pd.DataFrame(df,index=[0])
df.to_csv(filelocation,sep=' ',index=False)

# %%
import os, shutil

dest='/sim_details/simulation_config.json'
source = 'simulation_config.json'
fulldest=os.path.join(os.getcwd()+dest)
shutil.copy(source,fulldest)
# Out:
# 'D:\\BMTKtemp\\stylized single cell/sim_details/simulation_config.json'

# %% [markdown]
# #### Simulation

# %%
from bmtk.simulator import bionet

conf = bionet.Config.from_json('sim_details/simulation_config.json')
conf.build_env()
net = bionet.BioNetwork.from_config(conf)
sim = bionet.BioSimulator.from_config(conf, network=net)
sim.run()
# Out:
# 2020-09-26 22:02:13,994 [INFO] Created log file
# 2020-09-26 22:02:15,057 [INFO] Building cells.
# 2020-09-26 22:02:16,012 [INFO] Building recurrent connections
# 2020-09-26 22:02:16,086 [INFO] Running simulation for 15.000 ms with the time step 0.025 ms
# 2020-09-26 22:02:16,090 [INFO] Starting timestep: 0 at t_sim: 0.000 ms
# 2020-09-26 22:02:16,093 [INFO] Block save every 600 steps
# 2020-09-26 22:02:16,238 [INFO]     step:600 t_sim:15.00 ms
# 2020-09-26 22:02:16,303 [INFO] Simulation completed in 0.2172 seconds

# %% [markdown]
# #### Calculate LFP
# Define the function for calculating the LFP (convert this into delfi simulator)

# %%
from copy import deepcopy
import numpy as np
from bmtk.simulator.core.simulator import Simulator
from bmtk.simulator.bionet.modules.ecp import EcpMod

def calc_lfp(sim,Imem,Elec_pos,gid=0,sigma=0.3):
    assert isinstance(sim,Simulator), "first input should be an instance of class Simulator."
    try:
        ecp_ind = [isinstance(mod,EcpMod) for mod in sim._sim_mods].index(True)
    except ValueError:
        raise LookupError("no ecp module found.")
    rel = deepcopy(sim._sim_mods[ecp_ind]._rel)
    if gid not in rel.transfer_resistances.keys(): raise LookupError("cell gid not found.")
    
    Imem = np.asarray(Imem)
    Elec_pos = np.asarray(Elec_pos)
    assert Imem.shape[1]==rel.transfer_resistances[gid].shape[1],\
    "Imem 2nd dimemsion must have the same length as the number of segments in the selected cell."
    assert Elec_pos.ndim==2 and Elec_pos.shape[1]==3, "Elec_pos must be an n-by-3 2-D array."
    if type(sigma) is not float: raise TypeError("sigma must be float.")
    
    cell = sim.net.get_cell_gid(gid)
    rel.pos = Elec_pos.transpose()
    rel.nsites = Elec_pos.shape[0]
    rel.calc_transfer_resistance(gid,cell.get_seg_coords(),cell.morphology.seg_coords)
    if sigma!=0.3: rel.transfer_resistances[gid] = 0.3/sigma*rel.transfer_resistances[gid]
    return np.dot(Imem,rel.transfer_resistances[gid].transpose())

# %% [markdown]
# Load transmembrane recordings and initial electrodes location

# %%
import h5py
import numpy as np
import pandas as pd
import os

# Get transmembrane currents in "Im"
outpath = 'sim_details/output/'
filename = 'imem.h5'
im_file = outpath + filename
im_f = h5py.File(im_file,'r')
Im = im_f['report/mcortex/data'][()]
t = np.arange(*im_f['report/mcortex/mapping/time']) # array of time
im_f.close()

Vm_file = outpath + 'v_report.h5'
Vm_f = h5py.File(Vm_file,'r')
Vm = Vm_f['report/mcortex/data'][()]
Vm_f.close()

# Get initial position of electrodes in "pos"
elec_file = 'linear_electrode.csv'
# filelocation = 'sim_details/components/recXelectrodes'
elec_destpath = os.path.join(os.getcwd(),elec_file)
pos = pd.read_csv(elec_destpath,sep=' ')[[x+'_pos' for x in list('xyz')]].values

# %% [markdown]
# #### Random relocate electrodes

# %%
import numpy as np
from scipy.spatial.transform import Rotation as R

def newposition(translate,rotate,old_position=[0.,0.,0.],new_coordinate=True):
    translate = np.asarray(translate)
    old_position = np.asarray(old_position)
    Rot = R.from_euler('yzy',[rotate[0],-np.arccos(rotate[1]),rotate[2]]) # angles: alpha, theta=arcsin(h), phi
    if new_coordinate:
        new_position = Rot.inv().apply(old_position-translate)
    else:
        new_position = Rot.apply(old_position)+translate
    return new_position

# the range of 4 parameters (uniform prior) of cell position
# center coordinates (x,y), orientation unit vector (elevation height y, azimuth angle phi in xz-plane) all uniformly distributed
prior_min = np.array([-1000,-1000,-1,-np.pi])
prior_max = np.array([1000,1000,1,np.pi])

# %% [markdown]
# Example of LFP from new electrode position

# %%
# generate one example of 4 parameters for relocating the cell
params = np.array([np.random.uniform(prior_min[i],prior_max[i]) for i in range(prior_min.size)])
translate = np.insert(params[:2],2,0.) # translate cell along x,y only
rotate = np.insert(params[2:],0,0.) # do not spin, only change orientation of the cell
print(translate)
print(rotate)

# new_coordinate=True. Using coordinate system of the cell to represent electrode position,
# Equivalent to relocating the cell with the electrodes unmoved
newpos = newposition(translate,rotate,pos) 
lfp_new = calc_lfp(sim,Im,newpos,gid=0)
# Out:
# [793.70064458 -31.64323609   0.        ]
# [ 0.          0.29701257 -2.78702344]

# %% [markdown]
# Plot example LFP recordings

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(10,4))
plt.plot(t,Vm)

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

_,ax = plt.subplots(2,1,figsize=(8,6))
idx = (t>=5) & (t<=15)
ax[0].set_title('LFP from all electrodes')
for i in range(lfp_new.shape[1]):
    ax[0].plot(t[idx],lfp_new[idx,i], label='ch'+str(i))
ax[0].legend(loc=1)

ax[1].set_xlabel('ms')
for i in range(lfp_new.shape[1]):
    ax[1].plot(t,lfp_new[:,i],color=ax[0].lines[i].get_color())
# Out:
# <img src="data:image/png;base64,..." width="576">
